# %%
import sys
import subprocess
import torch
import torchvision
import csv
import datetime
import time
import shap
import gc
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors # For distinct colors
sys.path.append("./utils")
from utils.MLUtils import TrainerBase, cv_trainer
from MyModels import GrindingPredictor
from MyDataset import allowed_input_types, MemoryDataset, get_dataset, get_collate_fn

# %%
cpus = [32, 16, 2, 1]
percentage=[0.6, 0.8, 0.90, 1]
dataset = get_dataset(input_type='all', dataset_mode='classical', cpus=1, percentage=percentage)
# collate_fn = get_collate_fn(input_type=args.input_type)
gc.collect()
# print(f"Dataset loaded in {time.time()-_time:.2f} seconds")
print(f"Dataset size: {sys.getsizeof(dataset)}")
print("*" * 50)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 cpus = [32, 16, 2, 1]
#       2 percentage=[0.6, 0.8, 0.90, 1]
# ----> 3 dataset = get_dataset(input_type='all', dataset_mode='classical', cpus=1, percentage=percentage)
#       4 # collate_fn = get_collate_fn(input_type=args.input_type)
#       5 gc.collect()
#
# File c:\Users\Public\Documents\LocalWork\Smart_Grinding\MyDataset.py:282, in get_dataset(input_type, dataset_mode, cpus, percentage)
#     281 def get_dataset(input_type: str = "all", dataset_mode: str = "classical",cpus = [logical_threads,1], percentage = [0.6, 1.0]):
# --> 282     data = load_init_data()
#     283     grinding_data = data['grinding_data']
#     284     if input_type not in allowed_input_types:
#
# File c:\Users\Public\Documents\LocalWork\Smart_Grinding\MyDataset.py:345, in load_init_data()
#     343 def load_init_data():
#     344     grinding_data = GrindingData(project_dir)
# --> 345     grinding_data._load_all_physics_data()
#     346     return {
#     347         "dataDir_ae": dataDir_ae,
#     348         "dataDir_vib": dataDir_vib,
#     349         "grinding_data": grinding_data
#     350     }
#
# File c:\Users\Public\Documents\LocalWork\Smart_Grinding\GrindingData.py:578, in GrindingData._load_all_physics_data(self, save_dir)
#     574 # for filename in os.listdir(save_dir):
#     575 for filename in self.fn_names:
#     576     # if filename.endswith("_physics.npz"):
#     577         # Load the compressed data
# --> 578     loaded = np.load(os.path.join(save_dir, f"{filename}_physics.npz"))
#     580     # Convert the loaded data back to a dictionary
#     581     data = {key: loaded[key] for key in loaded.files}
#
# File c:\Users\mingwucn\.conda\envs\ai\Lib\site-packages\numpy\lib\_npyio_impl.py:459, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     457     own_fid = False
#     458 else:
# --> 459     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     460     own_fid = True
#     462 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Public\\Documents\\Data\\Grinding\\XiAnJiaoTong\\intermediate\\1-01-0_physics.npz'
